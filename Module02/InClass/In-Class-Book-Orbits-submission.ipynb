# %%
import numpy as np
from scipy import integrate
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## $m_2a = - \frac{Gm_1m_2}{r^2}$
# ## We can rewrite this as:
# ## * $\dot{x} = \frac{dx}{dt} = v_x$
# ## * $\ddot{x} = \frac{d^2x}{dt^2} = \frac{dv_x}{dt} = -\frac{GM_E}{r^{3/2}}x$
#
# In General
#
# ## * $\vec{\dot{u}} = \vec{v}$
# ## * $\vec{\ddot{u}} = -\frac{GM_E}{r^{3/2}}\vec{u}$

# %% [markdown]
# ## Complete the function below where we will treat state as a vector containing 6 elements:
#
# ## $$state = [x,y,z,v_x,v_y,v_z]$$

# %%
def model_2BP(t,state):
    ME = 5.98E+24
    G  = 6.67E-11 
    mu = ME*G*1E-9  # Earth's gravitational parameter = M*G  
                          # [km^3/s^2]
    x = state[0]
    y = state[1]
    z = state[2]
    
    x_dot = state[3]
    y_dot = state[4]
    z_dot = state[5]
    
    x_ddot = -mu * x / (x ** 2 + y ** 2 + z ** 2) ** (3 / 2)
    y_ddot = -mu * y / (x ** 2 + y ** 2 + z ** 2) ** (3 / 2)
    z_ddot = -mu * z / (x ** 2 + y ** 2 + z ** 2) ** (3 / 2)
    
    dstate_dt = [x_dot, y_dot, z_dot, x_ddot, y_ddot, z_ddot]
    return dstate_dt

# %% [markdown]
# ## We will look at the orbit of the Internation Space Station. The initial conditons are defined below

# %%
# Initial Conditions / ISS
X_0 = -2775.03475
Y_0 = 4524.24941
Z_0 = 4207.43331
VX_0 = -3.641793088
VY_0 = -5.665088604
VZ_0 =  3.679500667

# %% [markdown]
#  ### 1. Create an crete an initial state vector called $\it{\mathrm{state\_0}}$ array containing the initial position and veolcity information.
#  ### 2. Then define a time array using $\it{\mathrm{linspace}}$ that starts at 0s and covers 21,600s containing 2000 points
#  ### 3. Use Scipy's $\it{\mathrm{integrate.solve\_ivp}}$ to solve the ODEs

# %%
state_0 = [X_0, Y_0, Z_0, VX_0, VY_0, VZ_0]
t = np.linspace(0,21600,2000)
sol = integrate.solve_ivp(model_2BP, [t[0],t[-1]], state_0, method='DOP853', t_eval=t )
xsol = sol.y[0]  
ysol = sol.y[1]  
zsol = sol.y[2]
xsol
# Out:
# array([-2775.03475   , -2814.17682722, -2852.8970676 , ...,
#         -128.80808041,  -180.83247781,  -232.7904984 ])

# %% [markdown]
# # Analyze the Results
#
# Make plots of X vs. time
# 1. X vs. time, Y vs, time, Z vs. time
# 2. X vs. Y, X vs. Z, Y vs. Z

# %%
fig, axes = plt.subplots(3,1)
#plot
axes[0].plot(sol.t, xsol)
axes[1].plot(sol.t, ysol)
axes[2].plot(sol.t, zsol)
#titles
axes[0].set_title('X vs t')
axes[1].set_title('Y vs t')
axes[2].set_title('Z vs t')
#axes
axes[0].set_xlabel('t')
axes[0].set_ylabel('x')
axes[1].set_xlabel('t')
axes[1].set_ylabel('y')
axes[2].set_xlabel('t')
axes[2].set_ylabel('z')

plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(1,3)
#plot
axes[0].plot(sol.y[0],sol.y[1])
axes[1].plot(sol.y[0], sol.y[2])
axes[2].plot(sol.y[1], sol.y[2])
#titles
axes[0].set_title('X vs Y')
axes[1].set_title('X vs Z')
axes[2].set_title('Y vs Z')
#axes
axes[0].set_xlabel('Y')
axes[0].set_ylabel('X')
axes[1].set_xlabel('Z')
axes[1].set_ylabel('X')
axes[2].set_xlabel('Z')
axes[2].set_ylabel('Y')

plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D Plot
#
# Make a 3D plot showing the 3D trajectory of the ISS

# %%
# Setting up Spherical Earth to Plot
N = 50
phi = np.linspace(0, 2 * np.pi, N)
theta = np.linspace(0, np.pi, N)
theta, phi = np.meshgrid(theta, phi)

r_Earth = 6378.14  # Average radius of Earth [km]
X_Earth = r_Earth * np.cos(phi) * np.sin(theta)
Y_Earth = r_Earth * np.sin(phi) * np.sin(theta)
Z_Earth = r_Earth * np.cos(theta)

# Plotting Earth and Orbit
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X_Earth, Y_Earth, Z_Earth, color='blue', alpha=0.4)

#you need to redefine x_sat,y_sat, and z_sat to use your x,y,z solution array names
x_sat = xsol
y_sat = ysol
z_sat = zsol
ax.plot3D(x_sat, y_sat, z_sat, 'black')

#ax.view_init(30, 145)  # Changing viewing angle (adjust as needed)
plt.title('Two-Body Orbit')
ax.set_xlabel('X [km]')
ax.set_ylabel('Y [km]')
ax.set_zlabel('Z [km]');
# Out:
# <img src="data:image/png;base64,..." width="640">
